# %% [markdown]
# # 1. Data Loading

# %%
import numpy as np
import pandas as pd
import sklearn

#import warnings
#warnings.filterwarnings('ignore')

# The two packages below are for plotting
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# Type it in the first cell of your notebook, then your matplotlib plots will be included next to your codes. 
# Otherwise, include plt.show()

# %%
meat_2020_df = pd.read_excel("C:/Users/prath/OneDrive - The University of Texas at Dallas/MSBA/Predictive Analytics for Data Science/Conagra Hackathon/Conagra Project/Data/Fz_Rfg Substitute Meat_POS_2020.xlsx")

# %%
meat_2021_df = pd.read_excel("C:/Users/prath/OneDrive - The University of Texas at Dallas/MSBA/Predictive Analytics for Data Science/Conagra Hackathon/Conagra Project/Data/Fz_Rfg Substitute Meat_POS_2021.xlsx")

# %%
meat_2022_df = pd.read_excel("C:/Users/prath/OneDrive - The University of Texas at Dallas/MSBA/Predictive Analytics for Data Science/Conagra Hackathon/Conagra Project/Data/Fz_Rfg Substitute Meat_POS_2022.xlsx")

# %%
meat_2023_df = pd.read_excel("C:/Users/prath/OneDrive - The University of Texas at Dallas/MSBA/Predictive Analytics for Data Science/Conagra Hackathon/Conagra Project/Data/Fz_Rfg Substitute Meat_POS_2023.xlsx")

# %%
meat_2024_df = pd.read_excel("C:/Users/prath/OneDrive - The University of Texas at Dallas/MSBA/Predictive Analytics for Data Science/Conagra Hackathon/Conagra Project/Data/Fz_Rfg Substitute Meat_POS_2024.xlsx")

# %%
meat_sub_df = pd.concat([meat_2020_df, meat_2021_df, meat_2022_df, meat_2023_df, meat_2024_df])

# %%
meat_sub_df.to_csv('meat_sub_df.csv', index=False) # Converting the concatenated Dataset into CSV

# %%
meat_sub_df = pd.read_csv("meat_sub_df.csv")

# %%
meat_sub_df
# Out:
#                                     Geography                  Time  \
# 0              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 2              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 3              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 4              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# ...                                       ...                   ...
# 991775  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991776  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991777  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991778  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991779  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
#
#                                                   Product  UPC 13 digit  \
# 0       MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
# ...

# %%
meat_sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991780 entries, 0 to 991779
# Data columns (total 58 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   Geography                                        991780 non-null  object
#  1   Time                                             991780 non-null  object
#  2   Product                                          991780 non-null  object
#  3   UPC 13 digit                                     991780 non-null  int64
#  4   Unit Sales                                       991780 non-null  float64
#  5   Unit Sales No Merch                              971731 non-null  float64
#  6   Unit Sales Any Merch                             660538 non-null  float64
#  7   Unit Sales Price Reductions Only                 623096 non-null  float64
#  8   Unit Sales Feature Only                          119887 non-null  float64
# ...

# %%
meat_sub_df.shape
# Out:
# (991780, 58)

# %%
meat_sub_df.head()
# Out:
#                         Geography                  Time  \
# 0  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 2  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 3  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 4  Total US - Multi Outlet + Conv  Week Ending 01-12-20
#
#                                              Product  UPC 13 digit  \
# 0  MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
# 1  MATCH FROZEN ITALIAN SAUSAGE MEAT SUBSTITUTE B...  886844057111
# 2  ALPHA FROZEN ORIGINAL BEEFY MEAT SUBSTITUTE BU...  855099007621
# 3  ALPHA FROZEN ORIGINAL BEEFY MEAT SUBSTITUTE CR...  855099007601
# 4  ALPHA FROZEN REGULAR MEAT SUBSTITUTE PATTY 8 O...  855099007341
#
#    Unit Sales  Unit Sales No Merch  Unit Sales Any Merch  \
# 0   49.378093            49.378093                   NaN
# 1   38.459278            38.459278                   NaN
# ...

# %%
meat_sub_df.tail()
# Out:
#                                     Geography                  Time  \
# 991775  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991776  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991777  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991778  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
# 991779  West - Standard - Multi Outlet + Conv  Week Ending 01-21-24
#
#                                                   Product  UPC 13 digit  \
# 991775  UPTONS NATURALS REFRIGERATED REGULAR MEAT SUBS...  850010430201
# 991776  UPTONS NATURALS REFRIGERATED TRADITIONAL SEITA...  705105357712
# 991777  FRANKLIN FARMS REFRIGERATED CHICKEN PLANT BASE...   44325150511
# 991778  LIGHTLIFE SMART DELI REFRIGERATED TURKEY POULT...   43454100201
# 991779  PRIVATE LABEL REFRIGERATED SALT AND PEPPER PLA...      25347384
#
#          Unit Sales  Unit Sales No Merch  Unit Sales Any Merch  \
# ...

# %%
# So far we have loaded the data to Python and examined its structure
# The dataset has 58 variables and 991780 observations with a lot of missing data
# Now we will drop duplicateds records as a part of cleaning

# %%
meat_sub_df = meat_sub_df.drop_duplicates()
meat_sub_df.shape
# There are no duplicates in this dataset
# Out:
# (991780, 58)

# %% [markdown]
# # 2. Summary Statistics and Plots

# %%
meat_sub_df.describe()
# Out:
#        UPC 13 digit     Unit Sales  Unit Sales No Merch  Unit Sales Any Merch  \
# count  9.917800e+05  991780.000000        971731.000000         660538.000000
# mean   4.392101e+11    1908.249806          1398.953296            807.156753
# std    5.851710e+11    7413.283703          5111.330162           3748.108628
# min    3.213757e+06       0.010000             0.010000              0.011061
# 25%    2.898910e+10      32.803740            25.101394             12.000000
# 50%    8.086803e+10     220.166720           160.543548             69.041003
# 75%    8.422340e+11    1141.562945           871.126994            401.009580
# max    8.720165e+12  720358.990557        309661.380809         516178.762296
#
#        Unit Sales Price Reductions Only  Unit Sales Feature Only  \
# count                     623096.000000            119887.000000
# mean                         575.084562              1044.236340
# std                         2387.653659              3534.571281
# ...

# %%
y = meat_sub_df.loc[:,'Dollar Sales'] #Dollar sales can be our target variable
plt.hist(y,bins=15,range=(0,600))
# Out:
# (array([118160.,  52646.,  37757.,  30772.,  25457.,  21486.,  18749.,
#          17093.,  15640.,  14302.,  12721.,  11652.,  10888.,  10343.,
#           9445.]),
#  array([  0.,  40.,  80., 120., 160., 200., 240., 280., 320., 360., 400.,
#         440., 480., 520., 560., 600.]),
#  <BarContainer object of 15 artists>)

# %%
log_y = np.log(y)

plt.hist(log_y, bins=50, range=(1,15))
# Out:
# (array([3.7070e+03, 7.1670e+03, 1.0160e+04, 1.2095e+04, 1.1788e+04,
#         1.2742e+04, 1.4881e+04, 1.5290e+04, 1.7123e+04, 1.8436e+04,
#         2.0568e+04, 2.2652e+04, 2.5262e+04, 2.8204e+04, 3.0979e+04,
#         3.2923e+04, 3.4772e+04, 3.7543e+04, 3.8008e+04, 3.8868e+04,
#         3.9249e+04, 4.0581e+04, 4.1092e+04, 4.3481e+04, 4.3885e+04,
#         4.3696e+04, 4.1968e+04, 3.9119e+04, 3.7627e+04, 3.3948e+04,
#         2.9068e+04, 2.3115e+04, 2.2571e+04, 2.0951e+04, 1.6749e+04,
#         1.2598e+04, 9.0910e+03, 4.7550e+03, 3.0670e+03, 2.7360e+03,
#         2.6200e+03, 1.6780e+03, 1.5540e+03, 6.1700e+02, 2.6000e+02,
#         1.4900e+02, 1.1500e+02, 2.6000e+01, 1.2000e+01, 1.0000e+00]),
#  array([ 1.  ,  1.28,  1.56,  1.84,  2.12,  2.4 ,  2.68,  2.96,  3.24,
#          3.52,  3.8 ,  4.08,  4.36,  4.64,  4.92,  5.2 ,  5.48,  5.76,
#          6.04,  6.32,  6.6 ,  6.88,  7.16,  7.44,  7.72,  8.  ,  8.28,
#          8.56,  8.84,  9.12,  9.4 ,  9.68,  9.96, 10.24, 10.52, 10.8 ,
# ...
